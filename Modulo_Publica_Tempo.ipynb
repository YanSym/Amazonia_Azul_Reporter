# %% [markdown]
# ### Notebook para publicação de conteúdo do site Tideschart

# %%
# %load_ext autoreload
# %autoreload 2

from metodos_auxiliares_tempo import HelperClassTempo

# instancia o objeto
objeto_publicacao = HelperClassTempo()

# publicação
objeto_publicacao.publica_conteudo()
# Out:
# Intent: NORMAL
# 🤖 A previsão do tempo hoje em Ponta Negra (RN) é de céu parcialmente nublado [emoji_nuvem], com uma temperatura média de 28°C.
#
# Horários de maré alta: 2:43am (2,0m) e 3:00pm (2,1m).
# Horários de maré baixa: 9:36am (0,1m) e 9:17pm (0,1m).
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# 🤖 A previsão do tempo hoje em Ponta Negra (RN) é de céu parcialmente nublado 🌥, com uma temperatura média de 28°C.
#
# Horários de maré alta: 2:43am (2,0m) e 3:00pm (2,1m).
# Horários de maré baixa: 9:36am (0,1m) e 9:17pm (0,1m).
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# Tweet publicado
# Intent: TEMP_IGUAIS
# 🤖 Hoje em Morro de São Paulo (BA) a previsão do tempo é de céu parcialmente nublado [emoji_nuvem], com uma temperatura média de 27°C.
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# 🤖 Hoje em Morro de São Paulo (BA) a previsão do tempo é de céu parcialmente nublado 🌥, com uma temperatura média de 27°C.
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# Tweet publicado
# Intent: TEMP_IGUAIS
# 🤖 Hoje em Praia Grande (SP) a previsão do tempo é de céu parcialmente nublado [emoji_nuvem], com uma temperatura média de 27°C.
# As temperaturas máxima e mínima previstas também são de 27°C. O por do sol será às 18:35. [emoji_sol]
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# 🤖 Hoje em Praia Grande (SP) a previsão do tempo é de céu parcialmente nublado 🌥, com uma temperatura média de 27°C.
# As temperaturas máxima e mínima previstas também são de 27°C. O por do sol será às 18:35. 🌤
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# Tweet publicado
# Intent: TEMP_IGUAIS
# 🤖 Bom dia! Como vocês estão?
# A previsão do tempo hoje em Pedra Grande (RN) é de céu parcialmente nublado [emoji_nuvem], com uma temperatura média de 28°C.
# As temperaturas máxima e mínima previstas também são de 28°C. O por do sol será às 17:42. [emoji_sol]
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# tweet não pode ser publicado
# Intent: TEMP_IGUAIS
# 🤖 Hoje em Ubatuba (SP) a previsão do tempo é de céu parcialmente nublado [emoji_nuvem], com uma temperatura média de 25°C.
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# 🤖 Hoje em Ubatuba (SP) a previsão do tempo é de céu parcialmente nublado 🌥, com uma temperatura média de 25°C.
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# Tweet publicado
# Intent: NORMAL
# 🤖 Hoje em Aracaju (SE) a previsão do tempo é de céu parcialmente nublado [emoji_nuvem], com uma temperatura média de 27°C.
#
# Horários de maré alta: 2:48am (2,0m) e 3:05pm (2,1m).
# Horários de maré baixa: 9:54am (0,1m) e 9:35pm (0,1m).
# Um bom dia para todos!
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# tweet não pode ser publicado
# Intent: TEMP_IGUAIS
# 🤖 A previsão do tempo é de céu parcialmente nublado [emoji_nuvem] em Guarujá (SP), com uma temperatura média de 27°C.
# Um bom dia para todos!
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# 🤖 A previsão do tempo é de céu parcialmente nublado 🌥 em Guarujá (SP), com uma temperatura média de 27°C.
# Um bom dia para todos!
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# Tweet publicado
# Intent: TEMP_IGUAIS
# 🤖 Hoje em Santos (SP) a previsão do tempo é de céu parcialmente nublado [emoji_nuvem], com uma temperatura média de 27°C.
# As temperaturas máxima e mínima previstas também são de 27°C. O por do sol será às 18:35. [emoji_sol]
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# 🤖 Hoje em Santos (SP) a previsão do tempo é de céu parcialmente nublado 🌥, com uma temperatura média de 27°C.
# As temperaturas máxima e mínima previstas também são de 27°C. O por do sol será às 18:35. 🌤
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# Tweet publicado
# Intent: TEMP_IGUAIS
# 🤖 Bom dia! Como vocês estão?
# A previsão do tempo hoje em São Sebastião (SP) é de céu parcialmente nublado [emoji_nuvem], com uma temperatura média de 26°C.
# O melhor horário para pescar é 21:59 - 23:59, mas evitem fazer pesca predatória! [emoji_pesca]
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# tweet não pode ser publicado
# Intent: NORMAL
# 🤖 Hoje em Lauro de Freitas (BA) a previsão do tempo é de céu parcialmente nublado [emoji_nuvem], com uma temperatura média de 27°C.
# A temperatura máxima prevista é de 28°C e a mínima de 27°C. O por do sol será às 17:57. [emoji_sol]
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# 🤖 Hoje em Lauro de Freitas (BA) a previsão do tempo é de céu parcialmente nublado 🌥, com uma temperatura média de 27°C.
# A temperatura máxima prevista é de 28°C e a mínima de 27°C. O por do sol será às 17:57. 🌤
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# Tweet publicado
# Intent: NORMAL
# 🤖 Hoje em João Pessoa (PB) a previsão do tempo é de chuva fraca, com uma temperatura média de 27°C. O por do sol será às 17:39.
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# 🤖 Hoje em João Pessoa (PB) a previsão do tempo é de chuva fraca, com uma temperatura média de 27°C. O por do sol será às 17:39.
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# Tweet publicado
# Intent: NORMAL
# 🤖 Bom dia! Como vocês estão?
# Hoje em Tibau do Sul (RN) a previsão do tempo é de céu parcialmente nublado [emoji_nuvem], com uma temperatura média de 27°C.
# A temperatura máxima prevista é de 28°C e a mínima de 27°C. O por do sol será às 17:39. [emoji_sol]
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# tweet não pode ser publicado
# Intent: VENTO_ALTO
# 🤖 Hoje em Barreirinhas (MA) a previsão do tempo é de céu parcialmente nublado [emoji_nuvem], com uma temperatura média de 28°C.
# A velocidade do vento hoje está mais elevada do que o normal (39 km/h).
# Desejamos um excelente dia para todos!
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# 🤖 Hoje em Barreirinhas (MA) a previsão do tempo é de céu parcialmente nublado 🌥, com uma temperatura média de 28°C.
# A velocidade do vento hoje está mais elevada do que o normal (39 km/h).
# Desejamos um excelente dia para todos!
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# Tweet publicado
# Intent: TEMP_IGUAIS
# 🤖 Hoje em Marechal Deodoro (AL) a previsão do tempo é de céu parcialmente nublado [emoji_nuvem], com uma temperatura média de 28°C.
# O melhor horário para pescar é 21:18 - 23:18, mas por favor evite pesca predatória! [emoji_pesca]
# Desejamos um bom dia para todos!
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# tweet não pode ser publicado
# Intent: TEMP_IGUAIS
# 🤖 Bom dia! Como vocês estão?
# A previsão do tempo é de céu parcialmente nublado [emoji_nuvem] em Paraty (RJ), com uma temperatura média de 25°C.
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# 🤖 Bom dia! Como vocês estão?
# A previsão do tempo é de céu parcialmente nublado 🌥 em Paraty (RJ), com uma temperatura média de 25°C.
#
#
# #AmazôniaAzul 🌅
# #redebotsdobem 🛰
# Tweet publicado
